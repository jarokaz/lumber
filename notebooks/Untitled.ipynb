# %%
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import json
from PIL import Image

# %matplotlib inline

# %%
json_file = '../scripts/image1.json'
data = json.load(open(json_file))

# %%
image = data['image']

# %%
image = np.array(image)
image = image.astype(np.uint8)

# %%
print(image)
# Out:
# [[[[215 169 103]
#    [218 174 108]
#    [215 168 102]
#    ...
#    [207 174 108]
#    [213 170 111]
#    [217 171 116]]
#
#   [[218 171 107]
#    [222 174 111]
#    [220 169 113]
#    ...
#    [194 154  81]
#    [199 153  92]
#    [204 157  99]]
#
#   [[212 167 103]
#    [209 162 104]
#    [213 169 110]
#    ...
#    [190 150  85]
#    [192 151  94]
#    [202 165  99]]
#
#   ...
#
#   [[224 184 127]
#    [225 184 131]
#    [228 186 128]
#    ...
#    [220 173 122]
#    [220 177 123]
#    [222 178 121]]
#
#   [[227 188 135]
#    [228 186 132]
#    [225 188 134]
#    ...
#    [210 160 101]
#    [216 170 110]
#    [217 169 116]]
#
#   [[227 187 125]
#    [225 191 131]
#    [226 190 129]
#    ...
#    [210 158  93]
#    [217 168 108]
#    [217 170 110]]]]

# %%
plt.imshow(image[0])

# %%
im1 = Image.open('../data/snapshots/development/st1012_dry_knot_10.PNG')

# %%
im1 = np.array(im1)

# %%
plt.imshow(im1)
